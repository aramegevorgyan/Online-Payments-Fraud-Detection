# %%
# %pip install plotly
# Out:
# error: externally-managed-environment
#
# × This environment is externally managed
# ╰─> To install Python packages system-wide, try 'pacman -S
#     python-xyz', where xyz is the package you are trying to
#     install.
#
#     If you wish to install a non-Arch-packaged Python package,
#     create a virtual environment using 'python -m venv path/to/venv'.
#     Then use path/to/venv/bin/python and path/to/venv/bin/pip.
#
#     If you wish to install a non-Arch packaged Python application,
#     it may be easiest to use 'pipx install xyz', which will manage a
#     virtual environment for you. Make sure you have python-pipx
#     installed via pacman.
#
# note: If you believe this is a mistake, please contact your Python installation or OS distribution provider. You can override this, at the risk of breaking your Python installation or OS, by passing --break-system-packages.
# hint: See PEP 668 for the detailed specification.
# ...

# %%
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier

columns = [
    'step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig', 
    'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud', 'isFlaggedFraud'
]

df = pd.read_csv("datasetmerd.csv",names=columns)

print("Done loading data")
# Out:
# /tmp/ipykernel_13444/143487302.py:12: DtypeWarning: Columns (0,2,4,5,7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("datasetmerd.csv",names=columns)
# Done loading data

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error 

df = pd.read_csv("datasetmerd.csv")

df["type"] = df["type"].map({
    "CASH_OUT": 1, 
    "PAYMENT": 2, 
    "CASH_IN": 3, 
    "TRANSFER": 4, 
    "DEBIT": 5
})
x = df.drop(columns=['isFraud', 'isFlaggedFraud', 'nameOrig', 'nameDest'])
y= df['isFraud'] 

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
accuracy = np.mean(y_pred == y_test)
print(f"Accuracy: {accuracy:.4f}")
# Out:
# Accuracy: 0.9997

# %%
import plotly.express as px

type_counts = df["type"].value_counts()


fig = px.pie(
    values=type_counts.values, 
    names=type_counts.index, 
    hole=0.5, 
    title="Distribution of Transaction Type"
)
fig.show()

# %%
fraud_counts = df["isFraud"].value_counts()
labels = ['Not Fraud', 'Fraud']

fig2 = px.pie(values=fraud_counts.values, 
              names=labels, 
              title="Proportion of Fraudulent Transactions")
fig2.show()
