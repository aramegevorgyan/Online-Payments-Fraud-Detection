# %%
import pandas as pd 
import numpy as np
#import plotly.express as px
import requests

data = "https://raw.githubusercontent.com/amankharwal/Website-data/master/tips.csv"

reponse = requests.get(data)

with open("tips.csv", "wb") as f:
    f.write(reponse.content)

print("file is made")
# Out:
# file is made

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error 

df = pd.read_csv("tips.csv")

df['sex'] = df['sex'].map({'Female': 0, 'Male': 1})
df['smoker'] = df['smoker'].map({'No': 0, 'Yes': 1})
df['day'] = df['day'].map({'Thur': 0, 'Fri': 1, 'Sat': 2, 'Sun': 3})
df['time'] = df['time'].map({'Lunch': 0, 'Dinner': 1})

x = df.drop(columns=['tip'])
# print(x)
y = df['tip']
#print(y)
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)

model = DecisionTreeRegressor()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print(mean_absolute_error(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_4177/1465762111.py in ?()
#      10 #print(y)
#      11 x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2)
#      12
#      13 model = DecisionTreeRegressor()
# ---> 14 model.fit(x_train, y_train)
#      15
#      16 y_pred = model.predict(x_test)
#      17 print(mean_absolute_error(y_test, y_pred))
#
# /usr/lib/python3.14/site-packages/sklearn/base.py in ?(estimator, *args, **kwargs)
#    1332                 skip_parameter_validation=(
#    1333                     prefer_skip_nested_validation or global_skip_validation
#    1334                 )
#    1335             ):
# -> 1336                 return fit_method(estimator, *args, **kwargs)
#
# /usr/lib/python3.14/site-packages/sklearn/tree/_classes.py in ?(self, X, y, sample_weight, check_input)
#    1403         self : DecisionTreeRegressor
#    1404             Fitted estimator.
#    1405         """
#    1406
# -> 1407         super()._fit(
#    1408             X,
#    1409             y,
#    1410             sample_weight=sample_weight,
#
# /usr/lib/python3.14/site-packages/sklearn/tree/_classes.py in ?(self, X, y, sample_weight, check_input, missing_values_in_feature_mask)
#     251             check_X_params = dict(
#     252                 dtype=DTYPE, accept_sparse="csc", ensure_all_finite=False
#     253             )
#     254             check_y_params = dict(ensure_2d=False, dtype=None)
# --> 255             X, y = validate_data(
#     256                 self, X, y, validate_separately=(check_X_params, check_y_params)
#     257             )
#     258
#
# /usr/lib/python3.14/site-packages/sklearn/utils/validation.py in ?(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2910             # :(
#    2911             check_X_params, check_y_params = validate_separately
#    2912             if "estimator" not in check_X_params:
#    2913                 check_X_params = {**default_check_params, **check_X_params}
# -> 2914             X = check_array(X, input_name="X", **check_X_params)
#    2915             if "estimator" not in check_y_params:
#    2916                 check_y_params = {**default_check_params, **check_y_params}
#    2917             y = check_array(y, input_name="y", **check_y_params)
#
# /usr/lib/python3.14/site-packages/sklearn/utils/validation.py in ?(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1019                         )
#    1020                     array = xp.astype(array, dtype, copy=False)
#    1021                 else:
#    1022                     array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
# -> 1023             except ComplexWarning as complex_warning:
#    1024                 raise ValueError(
#    1025                     "Complex data not supported\n{}\n".format(array)
#    1026                 ) from complex_warning
#
# /usr/lib/python3.14/site-packages/sklearn/utils/_array_api.py in ?(array, dtype, order, copy, xp, device)
#     874         # Use NumPy API to support order
#     875         if copy is True:
#     876             array = numpy.array(array, order=order, dtype=dtype)
#     877         else:
# --> 878             array = numpy.asarray(array, order=order, dtype=dtype)
#     879
#     880         # At this point array is a NumPy ndarray. We convert it to an array
#     881         # container that is consistent with the input's namespace.
#
# /usr/lib/python3.14/site-packages/pandas/core/generic.py in ?(self, dtype, copy)
#    2167             )
#    2168         values = self._values
#    2169         if copy is None:
#    2170             # Note: branch avoids `copy=None` for NumPy 1.x support
# -> 2171             arr = np.asarray(values, dtype=dtype)
#    2172         else:
#    2173             arr = np.array(values, dtype=dtype, copy=copy)
#    2174
#
# ValueError: could not convert string to float: 'Male'
